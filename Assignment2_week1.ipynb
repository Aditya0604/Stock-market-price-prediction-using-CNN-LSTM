# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
october_data=pd.read_csv("/content/data_october.csv")

# %%
november_data=pd.read_csv("/content/data_november.csv")

# %%
december_data=pd.read_csv("/content/data_december.csv")

# %%
october_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1               event_time event_type  product_id  \
# 0           0             0  2019-10-01 00:00:00 UTC       cart     5773203
# 1           1             1  2019-10-01 00:00:03 UTC       cart     5773353
# 2           2             2  2019-10-01 00:00:07 UTC       cart     5881589
# 3           3             3  2019-10-01 00:00:07 UTC       cart     5723490
# 4           4             4  2019-10-01 00:00:15 UTC       cart     5881449
#
#            category_id category_code   brand  price    user_id  \
# 0  1487580005134238553           NaN  runail   2.62  463240011
# 1  1487580005134238553           NaN  runail   2.62  463240011
# 2  2151191071051219817           NaN  lovely  13.48  429681830
# 3  1487580005134238553           NaN  runail   2.62  463240011
# 4  1487580013522845895           NaN  lovely   0.56  429681830
#
#                            user_session
# 0  26dd6e6e-4dac-4778-8d2c-92e149dab885
# 1  26dd6e6e-4dac-4778-8d2c-92e149dab885
# ...

# %%
november_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1               event_time        event_type  \
# 0           0             0  2019-11-01 00:00:02 UTC              view
# 1           1             1  2019-11-01 00:00:09 UTC              cart
# 2           2             2  2019-11-01 00:00:10 UTC              view
# 3           3             3  2019-11-01 00:00:11 UTC              cart
# 4           4             4  2019-11-01 00:00:24 UTC  remove_from_cart
#
#    product_id   category_id category_code     brand  price      user_id  \
# 0   5802432.0  1.487580e+18           NaN       NaN   0.32  562076640.0
# 1   5844397.0  1.487580e+18           NaN       NaN   2.38  553329724.0
# 2   5837166.0  1.783999e+18           NaN       pnb  22.22  556138645.0
# 3   5876812.0  1.487580e+18           NaN  jessnail   3.16  564506666.0
# 4   5826182.0  1.487580e+18           NaN       NaN   3.33  553329724.0
#
#                            user_session
# 0  09fafd6c-6c99-46b1-834f-33527f4de241
# ...

# %%
december_data.tail()
# Out:
#        Unnamed: 0  Unnamed: 0.1               event_time event_type  \
# 20281       20281       3533281  2019-12-31 23:59:39 UTC       view
# 20282       20282       3533282  2019-12-31 23:59:46 UTC       view
# 20283       20283       3533283  2019-12-31 23:59:51 UTC       view
# 20284       20284       3533284  2019-12-31 23:59:52 UTC       view
# 20285       20285       3533285  2019-12-31 23:59:57 UTC       view
#
#        product_id          category_id category_code   brand   price  \
# 20281     5683350  1487580005671109489           NaN  masura    2.84
# 20282     5888097  1487580013388628160           NaN    shik  179.05
# 20283       59975  1487580012096782476           NaN     NaN    7.14
# 20284     5775982  1783999063314661546           NaN     NaN   11.90
# 20285     5635090  1487580005754995573           NaN     NaN    4.44
#
#          user_id                          user_session
# 20281  536812729  e4a2d47c-a956-4c46-8176-745f52ea664b
# ...

# %%
october_data.shape
# Out:
# (22283, 11)

# %%
november_data.shape
# Out:
# (20077, 11)

# %%
december_data.shape
# Out:
# (20286, 11)

# %%
total_data = pd.concat([october_data,november_data ,december_data])
total_data.shape
# Out:
# (62646, 11)

# %%
20286+20077+22283
# Out:
# 62646

# %%
total_data
# Out:
#        Unnamed: 0  Unnamed: 0.1               event_time event_type  \
# 0               0             0  2019-10-01 00:00:00 UTC       cart
# 1               1             1  2019-10-01 00:00:03 UTC       cart
# 2               2             2  2019-10-01 00:00:07 UTC       cart
# 3               3             3  2019-10-01 00:00:07 UTC       cart
# 4               4             4  2019-10-01 00:00:15 UTC       cart
# ...           ...           ...                      ...        ...
# 20281       20281       3533281  2019-12-31 23:59:39 UTC       view
# 20282       20282       3533282  2019-12-31 23:59:46 UTC       view
# 20283       20283       3533283  2019-12-31 23:59:51 UTC       view
# 20284       20284       3533284  2019-12-31 23:59:52 UTC       view
# 20285       20285       3533285  2019-12-31 23:59:57 UTC       view
#
#        product_id   category_id category_code   brand   price      user_id  \
# ...

# %%
october_data['brand'].value_counts()
# Out:
# runail          2637
# irisk           1121
# masura           718
# bpw.style        652
# ingarden         433
#                 ...
# lebelage           1
# sun                1
# lsanic             1
# ypsed              1
# rocknailstar       1
# Name: brand, Length: 169, dtype: int64

# %%
november_data['brand'].value_counts()
# Out:
# irisk          1556
# runail         1343
# masura          955
# grattol         628
# bpw.style       505
#                ...
# lowence           1
# sanoto            1
# tazol             1
# treaclemoon       1
# sun               1
# Name: brand, Length: 179, dtype: int64

# %%
december_data['brand'].value_counts()
# Out:
# runail         1531
# masura         1333
# irisk           829
# grattol         816
# bpw.style       663
#                ...
# profhenna         1
# kims              1
# dr.gloderm        1
# meisterwerk       1
# koreatida         1
# Name: brand, Length: 170, dtype: int64

# %%
total_data['brand'].value_counts()
# Out:
# runail       5511
# irisk        3506
# masura       3006
# bpw.style    1820
# grattol      1807
#              ...
# labay           1
# busch           1
# bosnic          1
# rasyan          1
# blise           1
# Name: brand, Length: 203, dtype: int64

# %%
october_data['user_id'].value_counts()
# Out:
# 265366822    221
# 397818974    208
# 398597138    158
# 528971009    144
# 558595163    138
#             ...
# 555325630      1
# 555471562      1
# 532924318      1
# 519346878      1
# 566280798      1
# Name: user_id, Length: 3270, dtype: int64

# %%
november_data['user_id'].value_counts()
# Out:
# 557908761.0    379
# 434112804.0    172
# 475333301.0    165
# 528015061.0    164
# 548895798.0    140
#               ...
# 566333219.0      1
# 566333191.0      1
# 428770850.0      1
# 566333156.0      1
# 553734056.0      1
# Name: user_id, Length: 3298, dtype: int64

# %%
december_data['user_id'].value_counts()
# Out:
# 576802932    699
# 580053614    253
# 554201837    201
# 564658360    185
# 580047208    179
#             ...
# 444490611      1
# 558153152      1
# 580071703      1
# 527028769      1
# 595414541      1
# Name: user_id, Length: 3211, dtype: int64

# %%
total_data['user_id'].value_counts()
# Out:
# 576802932.0    699
# 557908761.0    379
# 580053614.0    253
# 265366822.0    222
# 397818974.0    208
#               ...
# 347282313.0      1
# 555517367.0      1
# 550552163.0      1
# 566354528.0      1
# 595414541.0      1
# Name: user_id, Length: 9618, dtype: int64

# %%
october_data['product_id'].value_counts()
# Out:
# 5886064    121
# 5892179     72
# 5700037     72
# 5849033     66
# 5802432     63
#           ...
# 5724622      1
# 5873431      1
# 5880530      1
# 5846457      1
# 5885631      1
# Name: product_id, Length: 8149, dtype: int64

# %%
november_data['product_id'].value_counts()
# Out:
# 5892179.0    103
# 5809910.0     87
# 5849033.0     66
# 5900651.0     61
# 5760173.0     55
#             ...
# 5846106.0      1
# 5683551.0      1
# 5699772.0      1
# 5882348.0      1
# 5792813.0      1
# Name: product_id, Length: 7626, dtype: int64

# %%
december_data['product_id'].value_counts()
# Out:
# 5809910    189
# 5802432    128
# 5809824    104
# 5815662     89
# 5809912     76
#           ...
# 5739443      1
# 5754907      1
# 5903946      1
# 5848317      1
# 5635090      1
# Name: product_id, Length: 7267, dtype: int64

# %%
total_data['product_id'].value_counts()
# Out:
# 5809910.0    297
# 5802432.0    221
# 5892179.0    186
# 5700037.0    175
# 5849033.0    171
#             ...
# 5804366.0      1
# 5693499.0      1
# 5869355.0      1
# 5650583.0      1
# 5858475.0      1
# Name: product_id, Length: 15718, dtype: int64

# %%
october_data['event_type'].value_counts()
# Out:
# view                9371
# cart                6565
# remove_from_cart    4625
# purchase            1722
# Name: event_type, dtype: int64

# %%
november_data['event_type'].value_counts()
# Out:
# view                9380
# cart                5485
# remove_from_cart    3810
# purchase            1401
# Name: event_type, dtype: int64

# %%
december_data['event_type'].value_counts()
# Out:
# view                9050
# cart                5719
# remove_from_cart    4171
# purchase            1346
# Name: event_type, dtype: int64

# %%
total_data['event_type'].value_counts()
# Out:
# view                27801
# cart                17769
# remove_from_cart    12606
# purchase             4469
# Name: event_type, dtype: int64
